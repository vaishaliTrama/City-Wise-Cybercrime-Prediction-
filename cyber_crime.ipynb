# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Dell\\Documents\\vaishaliml\\cyber_crime_dataset.csv")

# %%
df['City'].unique()
# Out:
# array(['Agra', 'Allahabad', 'Amritsar', 'Asansol', 'Aurangabad', 'Bhopal',
#        'Chandigarh City', 'Dhanbad', 'Durg-Bhilainagar', 'Faridabad',
#        'Gwalior', 'Jabalpur', 'Jamshedpur', 'Jodhpur', 'Kannur', 'Kollam',
#        'Kota', 'Ludhiana', 'Madurai', 'Malappuram', 'Meerut', 'Nasik',
#        'Raipur', 'Rajkot', 'Ranchi', 'Srinagar', 'Thiruvananthapuram',
#        'Thrissur', 'Tiruchirapalli', 'Vadodara', 'Varanasi',
#        'Vasai Virar', 'Vijayawada', 'Vishakhapatnam', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Total State(s)', 'A&N Islands', 'Chandigarh',
# ...

# %%
df
# Out:
#                 City  Personal Revenge  Anger  Fraud  Extortion  \
# 0               Agra                 5      0     19          0
# 1          Allahabad                 0      0    222         11
# 2           Amritsar                 2      0      5          0
# 3            Asansol                 6      1      3          0
# 4         Aurangabad                 5      2     51          0
# ..               ...               ...    ...    ...        ...
# 185           Ladakh                 0      0      0          0
# 186      Lakshadweep                 2      0      0          0
# 187       Puducherry                 0      0      4          3
# 188      Total UT(s)                 7      8     67         29
# 189  Total All India              1470    822  30142       2440
#
#      Causing Disrepute  Prank  Sexual Exploitation  Disrupt Public Service  \
# 0                    0      0                    0                       0
# ...

# %%
df['City'].replace({'Agra':'1', 'Allahabad':'2', 'Amritsar':'3', 'Asansol':'4', 'Aurangabad':'5', 'Bhopal':'6',
       'Chandigarh City':'7', 'Dhanbad':'8', 'Durg-Bhilainagar':'9', 'Faridabad':'10',
       'Gwalior':'11', 'Jabalpur':'12', 'Jamshedpur':'13', 'Jodhpur':'14', 'Kannur':'15', 'Kollam':'16',
       'Kota':'17', 'Ludhiana':'18', 'Madurai':'19', 'Malappuram':'20', 'Meerut':'21', 'Nasik':'22',
       'Raipur':'23', 'Rajkot':'24', 'Ranchi':'25', 'Srinagar':'26', 'Thiruvananthapuram':'27',
       'Thrissur':'28', 'Tiruchirapalli':'29', 'Vadodara':'30', 'Varanasi':'31',
       'Vasai Virar':'31', 'Vijayawada':'32', 'Vishakhapatnam':'33', 'Andhra Pradesh':'34',
       'Arunachal Pradesh':'35', 'Assam':'36', 'Bihar':'37', 'Chhattisgarh':'38', 'Goa':'39',
       'Gujarat':'40', 'Haryana':'41', 'Himachal Pradesh':'42', 'Jammu & Kashmir':'43',
       'Jharkhand':'44', 'Karnataka':'45', 'Kerala':'46', 'Madhya Pradesh':'47',
       'Maharashtra':'48', 'Manipur':'49', 'Meghalaya':'50', 'Mizoram':'51', 'Nagaland':'52',
       'Odisha':'53', 'Punjab':'54', 'Rajasthan':'55', 'Sikkim':'56', 'Tamil Nadu':'57',
       'Telangana':'58', 'Tripura':'59', 'Uttar Pradesh':'60', 'Uttarakhand':'61',
       'West Bengal':'61', 'Total State(s)':'62', 'A&N Islands':'63', 'Chandigarh':'64',
       'D&N Haveli':'65', 'Daman & Diu':'66', 'Delhi':'67', 'Lakshadweep':'68', 'Puducherry':'69',
       'Total UT(s)':'70', 'Total All India':'71', 'TOTAL STATE(S)':'72',
       'A & N Islands':'73', 'D & N Haveli':'74', 'TOTAL UT(S)':'75', 'TOTAL ALL INDIA':'76',
       'D & N Haveli and Daman & Diu':'77', 'Ladakh':'78'},inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15440\3152745876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].replace({'Agra':'1', 'Allahabad':'2', 'Amritsar':'3', 'Asansol':'4', 'Aurangabad':'5', 'Bhopal':'6',

# %%
df
# Out:
#     City  Personal Revenge  Anger  Fraud  Extortion  Causing Disrepute  Prank  \
# 0      1                 5      0     19          0                  0      0
# 1      2                 0      0    222         11                  8      0
# 2      3                 2      0      5          0                  0      0
# 3      4                 6      1      3          0                  0      0
# 4      5                 5      2     51          0                  0      0
# ..   ...               ...    ...    ...        ...                ...    ...
# 185   78                 0      0      0          0                  0      0
# 186   68                 2      0      0          0                  0      0
# 187   69                 0      0      4          3                  0      0
# 188   70                 7      8     67         29                 28      2
# 189   71              1470    822  30142       2440               1706    254
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['City', 'Personal Revenge', 'Anger', 'Fraud', 'Extortion', 'Causing Disrepute', 'Prank',
        'Sexual Exploitation', 'Disrupt Public Service', 'Sale purchase illegal drugs',
        'Developing own business', 'Spreading Piracy', 'Psycho or Pervert', 'Steal Information',
        'Abetment to Suicide', 'Others', 'Total']]

# %%
y = df['City']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_train)
# Out:
# 152

# %%
len(X_test)
# Out:
# 38

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.predict(X_test)
# Out:
# array(['61', '36', '61', '48', '61', '61', '61', '60', '58', '61', '36',
#        '36', '36', '61', '36', '36', '61', '36', '62', '58', '61', '48',
#        '58', '61', '61', '61', '61', '60', '58', '53', '61', '36', '62',
#        '40', '61', '61', '60', '61'], dtype=object)

# %%
X_test
# Out:
#     City  Personal Revenge  Anger  Fraud  Extortion  Causing Disrepute  Prank  \
# 56    56                 0      0      0          0                  0      0
# 62    61                 8      3     45          7                 15     17
# 155   38                 0      1     75          7                 41      0
# 48    48                47     80   2171         23                 97     16
# 28    29                 1      0      0          0                  0      0
# 80    41                 6      9    137         21                 11      2
# 146   67                 4      0     31         15                  0      1
# 47    47                 2     26    155          6                135      4
# 44    44                31     11    460         17                  0      6
# 59    59                 0      2      3          0                  0      0
# 96    57                39     13     55          7                 17      6
# ...

# %%
lr.score(X_test,y_test)
# Out:
# 0.07894736842105263
